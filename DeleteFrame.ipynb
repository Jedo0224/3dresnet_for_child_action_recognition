# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import os
from PIL import Image
import shutil

# %%
 # connect google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#
from torchvision.transforms import ToTensor, ToPILImage
from PIL import Image
import numpy as np
import torch

import os

# data_path='/content/drive/MyDrive/RA/img/cr'



#frames = [frame1, frame2, lframe3] # list of frame objects
for y in range(1,11):

  for i in range(0,13):
    
    files='/content/drive/MyDrive/gifs/keypoint_{}/action_{}'.format(y,i)
    file_list=os.listdir(files)

 
    
    a=[]

    for j in file_list:
        
        name='/content/drive/MyDrive/imgs/keypoint_{}/action_{}/{}'.format(y,i,j)
        name_list = os.listdir(name)
        for w in name_list:
          file_name='/content/drive/MyDrive/imgs/keypoint_{}/action_{}/{}/{}'.format(y,i,j,w)
         
          img = Image.open(file_name).resize([120,120])
          img.shape
          #print(a)

# %%
from PIL import Image, ImageSequence




for i in range(0,13):
    
    files='/content/drive/MyDrive/action/action_{}'.format(i)
    dirListing = os.listdir(files)

    
    for j in dirListing:
        action_list= os.path.join(files, j)

        image = Image.open(action_list)

  # Get the number of frames
        frame_count = 0
        for frame in ImageSequence.Iterator(image):
            frame_count += 1

        print("{} : The number of frames in the image is {}".format(j,frame_count))
        if frame_count<40:
          os.remove(action_list)
          print("del_complete")
# Out:
# animation.0.2023-02-19 09:19:37.055229.gif : The number of frames in the image is 40
# animation.0.2023-02-19 09:19:37.571694.gif : The number of frames in the image is 40
# animation.0.2023-02-19 09:19:38.106856.gif : The number of frames in the image is 40
# animation.0.2023-02-19 09:19:38.563706.gif : The number of frames in the image is 40
# animation.0.2023-02-19 09:19:39.095010.gif : The number of frames in the image is 40
# animation.0.2023-02-19 09:19:39.549530.gif : The number of frames in the image is 40
# animation.0.2023-02-19 09:19:40.077660.gif : The number of frames in the image is 40
# animation.0.2023-02-19 09:19:40.546413.gif : The number of frames in the image is 39
# del_complete
# animation.0.2023-02-19 09:19:41.518979.gif : The number of frames in the image is 40
# animation.0.2023-02-19 09:19:41.958736.gif : The number of frames in the image is 40
# animation.0.2023-02-19 09:19:42.407593.gif : The number of frames in the image is 40
# ...

# %%
def get_files_count(folder_path):
	dirListing = os.listdir(folder_path)
 
	return len(dirListing)

for i in range(0,13):
    path = "/content/drive/MyDrive/action/action_{}".format(i)
    dirListing = os.listdir(path)
    a = "action_{} : ".format(i)
    print(a ,len(dirListing))
# Out:
# action_0 :  277
# action_1 :  237
# action_2 :  193
# action_3 :  229
# action_4 :  259
# action_5 :  274
# action_6 :  389
# action_7 :  295
# action_8 :  218
# action_9 :  288
# action_10 :  210
# action_11 :  324
# action_12 :  229

# %%
# !pip install split-folders

# %cd /content/drive/MyDrive/
import splitfolders
splitfolders.fixed("/content/drive/MyDrive/action", output="dataset_0", seed=1337, fixed=(116 ,39 ,37))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# /content/drive/MyDrive
# Copying files: 2496 files [00:38, 64.02 files/s]
